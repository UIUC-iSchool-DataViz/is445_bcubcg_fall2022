# %% [markdown]
# # In Class Notebook, Week 05

# %% [markdown]
# You can always paste the URL of this notebook (https://github.com/UIUC-iSchool-DataViz/is445_spring2022/blob/master/week05/inClass_week05.ipynb ) into the nbviewer interface for a plain-text rendering:
#
# https://kokes.github.io/nbviewer.js/viewer.html

# %%
# import our usual things
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

# %%
# also import widgets library
import ipywidgets

# %% [markdown]
# ## Review from last week

# %%
michigan_file = '/Users/jillnaiman/Downloads/michigan_lld.flt'
# can be found with tab completes!

# %%
np.fromfile?

# %%
michigan = np.fromfile(michigan_file,dtype='f4').reshape((5365,4201))

# %%
michigan.reshape(5356,4201)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t5/9xgccmv92hnfvjwd62mk8zqh0000gn/T/ipykernel_36484/4086525451.py in <module>
# ----> 1 michigan.reshape(5356,4201)
#
# ValueError: cannot reshape array of size 22538365 into shape (5356,4201)

# %%
michigan.reshape?

# %%
# take out -9999 tags for missing data
michigan[michigan==-9999] = np.nan

# %%
# step 0: even less fancy hardcoding
plt.imshow(michigan, cmap='seismic', norm=matplotlib.colors.SymLogNorm(10))
plt.colorbar() # put in a colorbar
plt.clim(-352, 352) # just to make the colormap centered around 0 (for divergent colormaps)
plt.show()
# Out:
# /Users/jillnaiman/anaconda3/envs/DataViz/lib/python3.7/site-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.

# %%
# step 1: hard code any parameters we may want to widgetize(?)
colormap_name = 'seismic'
take_log = True

if take_log:
    norm = matplotlib.colors.SymLogNorm(10) # symmetric log, base 10
else:
    norm = matplotlib.colors.Normalize() # "the usual" linear map
    
plt.imshow(michigan, cmap=colormap_name, norm=norm)
plt.colorbar() # put in a colorbar
plt.clim(-352, 352) # just to make the colormap centered around 0 (for divergent colormaps)
plt.show()
# Out:
# /Users/jillnaiman/anaconda3/envs/DataViz/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.

# %%
# step 2: turn this into a function with "hard coded" values as inputs
def michigan_plot(colormap_name, take_log=True):
    if take_log:
        norm = matplotlib.colors.SymLogNorm(10)
    else:
        norm = matplotlib.colors.Normalize()
    plt.imshow(michigan,cmap=colormap_name,norm=norm)
    plt.colorbar()
    plt.clim(-352,352)
    plt.show()

# %%
# step 2.5 -- try out your function!
michigan_plot('Blues',take_log=False)

# %%
# Step 3: use .interact to widgetize it!
@ipywidgets.interact(colormap_name=plt.colormaps(), take_log=True)
def michigan_plot(colormap_name, take_log=True):
    if take_log:
        norm = matplotlib.colors.SymLogNorm(10)
    else:
        norm = matplotlib.colors.Normalize()
    plt.imshow(michigan,cmap=colormap_name,norm=norm)
    plt.colorbar()
    plt.clim(-352,352)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='colormap_name', options=('Accent', 'Accent_r', 'Blues', 'Blues_r',…

# %%
buildings = pd.read_csv('https://uiuc-ischool-dataviz.github.io/is445_spring2022/week03/data/building_inventory.csv',
                       na_values={'Square Footage':0,
                                 'Year Acquired':0, 
                                 'Year Constructed':0,
                                 'Floors':0})

# %%
buildings.head()
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# 3  Astoria     61501  Fulton             17            Cheri Bustos        93
# 4  Astoria     61501  Fulton             17            Cheri Bustos        93
#
#        Rep Full Name  ...  Bldg Status Year Acquired Year Constructed  \
# 0  Hammond Norine K.  ...       In Use        1975.0           1975.0
# 1  Hammond Norine K.  ...       In Use        2004.0           2004.0
# 2  Hammond Norine K.  ...       In Use        2004.0           2004.0
# 3  Hammond Norine K.  ...       In Use        2004.0           2004.0
# 4  Hammond Norine K.  ...       In Use        2004.0           2004.0
#
#    Square Footage  Total Floors  Floors Above Grade  Floors Below Grade  \
# 0           144.0             1                   1                   0
# 1           144.0             1                   1                   0
# 2           144.0             1                   1                   0
# 3           144.0             1                   1                   0
# 4           144.0             1                   1                   0
#
#    Usage Description  Usage Description 2 Usage Description 3
# 0            Unusual              Unusual        Not provided
# 1            Unusual              Unusual        Not provided
# 2            Unusual              Unusual        Not provided
# 3            Unusual              Unusual        Not provided
# 4            Unusual              Unusual        Not provided
#
# [5 rows x 22 columns]

# %%
stats = buildings.groupby("Year Acquired")["Square Footage"].describe()

# %%
stats
# Out:
#                count           mean           std       min       25%  \
# Year Acquired
# 1753.0           1.0    1200.000000           NaN    1200.0    1200.0
# 1802.0           2.0    2220.000000   1943.129435     846.0    1533.0
# 1810.0           3.0    1344.333333   1809.945948     216.0     300.5
# 1832.0           1.0  120000.000000           NaN  120000.0  120000.0
# 1837.0           1.0   10302.000000           NaN   10302.0   10302.0
# ...              ...            ...           ...       ...       ...
# 2015.0          20.0   15254.650000  29153.085290     144.0     696.0
# 2016.0          10.0   30483.900000  61864.180491    1152.0    2464.0
# 2017.0           1.0    6720.000000           NaN    6720.0    6720.0
# 2018.0           4.0    4290.000000   5153.644342    1455.0    1455.0
# 2019.0           2.0     760.000000      0.000000     760.0     760.0
#
#                     50%        75%       max
# Year Acquired
# 1753.0           1200.0    1200.00    1200.0
# 1802.0           2220.0    2907.00    3594.0
# 1810.0            385.0    1908.50    3432.0
# 1832.0         120000.0  120000.00  120000.0
# 1837.0          10302.0   10302.00   10302.0
# ...                 ...        ...       ...
# 2015.0           3152.0   10590.25  105000.0
# 2016.0           3352.5    3793.00  184000.0
# 2017.0           6720.0    6720.00    6720.0
# 2018.0           1852.5    4687.50   12000.0
# 2019.0            760.0     760.00     760.0
#
# [171 rows x 8 columns]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# step 1: hard-code something
style = 'seaborn'

with plt.style.context(style):
    plt.plot(stats['max'], label='Max') # note "years" gets passed by default in the index
    plt.plot(stats['min'], label='Min')
    plt.xlabel('Years')
    plt.ylabel('Square Footage')
    plt.legend()
    plt.show()

# %%
stats['max']
# Out:
# Year Acquired
# 1753.0      1200.0
# 1802.0      3594.0
# 1810.0      3432.0
# 1832.0    120000.0
# 1837.0     10302.0
#             ...
# 2015.0    105000.0
# 2016.0    184000.0
# 2017.0      6720.0
# 2018.0     12000.0
# 2019.0       760.0
# Name: max, Length: 171, dtype: float64

# %%
# step 2 -- make into a function
#style = 'seaborn'

def make_buildings_plot(style):
    with plt.style.context(style):
        plt.plot(stats['max'], label='Max') # note "years" gets passed by default in the index
        plt.plot(stats['min'], label='Min')
        plt.xlabel('Years')
        plt.ylabel('Square Footage')
        plt.legend()
        plt.show()

# %%
# 2.5 test the function
make_buildings_plot('seaborn')

# %%
# step 3: widgetize it!

@ipywidgets.interact(style=plt.style.available)
def make_buildings_plot(style):
    with plt.style.context(style):
        plt.plot(stats['max'], label='Max') # note "years" gets passed by default in the index
        plt.plot(stats['min'], label='Min')
        #plt.plot(stats['max']*2)
        plt.xlabel('Years')
        plt.ylabel('Square Footage')
        #plt.yscale('log')
        plt.legend()
        plt.show()
# Out:
# interactive(children=(Dropdown(description='style', options=('Solarize_Light2', '_classic_test_patch', 'bmh', …

# %%
@ipywidgets.interact(style=plt.style.available)
def make_buildings_plot(style):
    with plt.style.context(style):
        fig, ax = plt.subplots(figsize=(5,5))
        ax.plot(stats['max'], label='Max') # note "years" gets passed by default in the index
        ax.plot(stats['min'], label='Min')
        ax.set_xlabel('Years')
        ax.set_ylabel('Square Footage')
        #plt.yscale('log')
        ax.legend()
        plt.show()
# Out:
# interactive(children=(Dropdown(description='style', options=('Solarize_Light2', '_classic_test_patch', 'bmh', …

# %% [markdown]
# ## Widgets on their own

# %%
itext = ipywidgets.IntText()
itext
# Out:
# IntText(value=0)

# %%
itext.value = 10

# %%
ip = ipywidgets.IntProgress(value=90)
ip
# Out:
# IntProgress(value=90)

# %%
irange = ipywidgets.IntSlider(min=0, max=100, step=1)

# %%
irange
# Out:
# IntSlider(value=0)

# %%
irange
# Out:
# IntSlider(value=89)

# %% [markdown]
# We want to figure out a way to link the progress bar's value to the changes we make on the irange slider.

# %%
ip.keys # keys of our progress bar widget
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'bar_style',
#  'description',
#  'description_tooltip',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'style',
#  'value']

# %%
irange.keys # keys for the integer range slider
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
ip
# Out:
# IntProgress(value=90)

# %%
ip.value = 10

# %%
irange
# Out:
# IntSlider(value=90)

# %%
irange.value = 50

# %%
ipywidgets.jslink?

# %%
# create a link on the "frontend" (whatever that means right now)
ipywidgets.jslink((ip,'value'),(irange,'value'))
# Out:
# Link(source=(IntProgress(value=10), 'value'), target=(IntSlider(value=50), 'value'))

# %%
ip
# Out:
# IntProgress(value=10)

# %%
irange
# Out:
# IntSlider(value=10)

# %%
# use the layout widget "VBox" to put them in a a vertical stack
ipywidgets.VBox([ip,irange])
# Out:
# VBox(children=(IntProgress(value=9), IntSlider(value=9)))

# %%
# linking on the backend with Python
ip2 = ipywidgets.IntProgress(value=90, max=200)
irange2 = ipywidgets.IntSlider(min=0,max=200,step=1)
ipywidgets.link((ip2,'value'),(irange2,'value'))
ipywidgets.VBox([ip2,irange2])
# Out:
# VBox(children=(IntProgress(value=90, max=200), IntSlider(value=90, max=200)))

# %%
ipywidgets.IntProgress?

# %%
button = ipywidgets.Button(description="I am a button.")
button
# Out:
# Button(description='I am a button.', style=ButtonStyle())
# I have been clicked! Woo.
# I have been clicked! Woo.

# %%
# let's define a function I want to run everytime I click this button
def say_click(event):
    print("I have been clicked! Woo.")

# %%
#button.keys function doesn't show up!

# %%
button.on_click(say_click)

# %%
# let's connect multiple widgets with functions
ip = ipywidgets.IntProgress()
ip
# Out:
# IntProgress(value=0)

# %%
button_plus = ipywidgets.Button(description="+10")
button_plus
# Out:
# Button(description='+10', style=ButtonStyle())

# %%
button_minus = ipywidgets.Button(description='-10')
button_minus
# Out:
# Button(description='-10', style=ButtonStyle())

# %%
# before linking anything, let's lay them out in a nice way
ipywidgets.HBox([button_minus, ip, button_plus])
# Out:
# HBox(children=(Button(description='-10', style=ButtonStyle()), IntProgress(value=0), Button(description='+10',…

# %%
ip.value
# Out:
# 0

# %%
ip.value=50

# %%
# a function that will decrease by 10 the progress bar when I click on the "button_minus"
# widget
def click_down(event):
    ip.value -= 10

# %%
# attach this function to my button minus widget
button_minus.on_click(click_down)

# %%
# on clicking the button_plus
def click_up(event):
    ip.value += 10
button_plus.on_click(click_up)

# %%
# tie a colorpicker and a slider
islider = ipywidgets.IntSlider(min=0,max=10,step=1, orientation='vertical')

# %%
islider
# Out:
# IntSlider(value=0, max=10, orientation='vertical')

# %%
islider.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
islider.style.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description_width',
#  'handle_color']

# %%
islider.style.handle_color='#750075' # HTML style HEX code for a color (16 mill)

# %%
islider
# Out:
# IntSlider(value=5, max=10, orientation='vertical', style=SliderStyle(handle_color='#750075'))

# %%
cp = ipywidgets.ColorPicker()
cp
# Out:
# ColorPicker(value='black')

# %%
ipywidgets.jslink((cp,'value'),(islider.style,'handle_color'))
# Out:
# Link(source=(ColorPicker(value='#f7f7f7'), 'value'), target=(SliderStyle(handle_color='#750075'), 'handle_colo…

# %%
ipywidgets.VBox([cp,islider])
# Out:
# VBox(children=(ColorPicker(value='#f7f7f7'), IntSlider(value=6, max=10, orientation='vertical', style=SliderSt…

# %%
class MyObject():
    name = 'unnamed'
    age = 0

# %%
# new variable of this type of class
my_obj = MyObject()

# %%
my_obj.name
# Out:
# 'unnamed'

# %%
my_obj.age
# Out:
# 0

# %%
my_obj.name = 'Bob'; my_obj.age = 47

# %%
print('Hello, my name is:', my_obj.name, 'and I am', my_obj.age, 'years old')
# Out:
# Hello, my name is: Bob and I am 47 years old

# %%
my_obj.name = 'Linda'; my_obj.age = 45

# %%
print('Hello, my name is:', my_obj.name, 'and I am', my_obj.age, 'years old')
# Out:
# Hello, my name is: Linda and I am 45 years old

# %%
import traitlets

# %%
class MyTraitletObject(traitlets.HasTraits):
    name = traitlets.Unicode("unnamed")
    age = traitlets.Int(0)

# %%
my_tobj = MyTraitletObject()

# %%
my_tobj.name
# Out:
# 'unnamed'

# %%
my_tobj.age
# Out:
# 0

# %%
my_tobj.name = 'Bob'
my_tobj.age = 47

# %%
print('Hello my name is:', my_tobj.name, 'and I am', my_tobj.age, 'years old')
# Out:
# Hello my name is: Bob and I am 47 years old

# %%
def name_change(change):
    print(change)
    
my_tobj.observe(name_change, ['name'])
# .observe is going to "watch" for changes in the traits of my_tobj
# name_change is the name of the function with the action we want
# ['name'] is the (potentially list) of traits we want observed

# %%
my_tobj.name = 'Linda'
# Out:
# {'name': 'name', 'old': 'Bob', 'new': 'Linda', 'owner': <__main__.MyTraitletObject object at 0x7f9d70904650>, 'type': 'change'}

# %%
def name_change2(change):
    #print('Hello my name is:', my_tobj.name, 'and I am', my_tobj.age, 'years old')
    print('Hello my name is:', change['new'], 'and I am', change['owner'].age, 'years old')
    
my_tobj.observe(name_change2, ['name'])

# %%
my_tobj.name = 'Bob'
# Out:
# {'name': 'name', 'old': 'Linda', 'new': 'Bob', 'owner': <__main__.MyTraitletObject object at 0x7f9d70904650>, 'type': 'change'}
# Hello my name is: Bob and I am 47 years old

# %%
# could re-define my_tobj or we can "unobserve" a function
my_tobj.unobserve(name_change,['name'])

# %%
my_tobj.name = 'Linda'
# Out:
# Hello my name is: Linda and I am 47 years old

# %%
my_tobj.age = 45

# %%
def age_change(change):
    print('Hello, my name is', change['owner'].name, 'and I am', change['new'], 'years old')
my_tobj.observe(age_change, ['age'])

# %%
my_tobj.name, my_tobj.age = 'Louise', 8
# Out:
# Hello my name is: Louise and I am 45 years old
# Hello, my name is Louise and I am 8 years old

# %%
def print_age_change(change):
    print(change)
my_tobj.observe(print_age_change,['age'])

# %%
my_tobj.age = 13
# Out:
# Hello, my name is Louise and I am 13 years old
# {'name': 'age', 'old': 8, 'new': 13, 'owner': <__main__.MyTraitletObject object at 0x7f9d70904650>, 'type': 'change'}

# %%
my_tobj.unobserve(print_age_change, ['age'])

# %%
my_tobj.age = 8
# Out:
# Hello, my name is Louise and I am 8 years old

# %% [markdown]
# ## Some widget customization
#
# (Possible extension to the HW, but not required!)

# %%
# Step 3: use .interact to widgetize it!
@ipywidgets.interact(colormap_name=plt.colormaps(), take_log=True)
def michigan_plot(colormap_name, take_log=True):
    if take_log:
        norm = matplotlib.colors.SymLogNorm(10)
    else:
        norm = matplotlib.colors.Normalize()
    plt.imshow(michigan,cmap=colormap_name,norm=norm)
    plt.colorbar()
    plt.clim(-352,352)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='colormap_name', options=('Accent', 'Accent_r', 'Blues', 'Blues_r',…

# %% [markdown]
# We want to mess with the style of the defaults for our widgets, so we can start building up our own.

# %%
ipywidgets.Dropdown?

# %%
cmap_widget = ipywidgets.Dropdown(options=plt.colormaps())
cmap_widget
# Out:
# Dropdown(options=('Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_…

# %%
cmap_widget = ipywidgets.Dropdown(options=plt.colormaps(), value='terrain')
cmap_widget
# Out:
# Dropdown(index=154, options=('Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'Bu…

# %%
cmap_widget.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_options_labels',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'index',
#  'layout',
#  'style']

# %%
cmap_widget = ipywidgets.Dropdown(options=plt.colormaps(),
                                 value='terrain',
                                 description='Select a colormap:')
cmap_widget
# Out:
# Dropdown(description='Select a colormap:', index=154, options=('Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG…

# %%
cmap_widget.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_options_labels',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'index',
#  'layout',
#  'style']

# %%
cmap_widget.layout.width='800px' #changes the size of the drop down, not quite what we want

# %%
cmap_widget.layout.width = '300px'
cmap_widget
# Out:
# Dropdown(description='Select a colormap:', index=154, layout=Layout(width='300px'), options=('Accent', 'Accent…

# %%
cmap_widget.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_options_labels',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'index',
#  'layout',
#  'style']

# %%
cmap_widget.style.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'description_width']

# %%
cmap_widget.style.description_width = '300px'
cmap_widget
# Out:
# Dropdown(description='Select a colormap:', index=154, layout=Layout(width='300px'), options=('Accent', 'Accent…

# %%
cmap_widget.style.description_width = 'initial'
cmap_widget
# Out:
# Dropdown(description='Select a colormap:', index=154, layout=Layout(width='300px'), options=('Accent', 'Accent…

# %%
ipywidgets.Checkbox?

# %%
log_check = ipywidgets.Checkbox(value=True, description='Take log of colormap?')
log_check
# Out:
# Checkbox(value=True, description='Take log of colormap?')

# %%
#@ipywidgets.interact(colormap_name=plt.colormaps(), take_log=True)
@ipywidgets.interact(colormap_name=cmap_widget, take_log=log_check)
def michigan_plot(colormap_name, take_log=True):
    if take_log:
        norm = matplotlib.colors.SymLogNorm(10)
    else:
        norm = matplotlib.colors.Normalize()
    plt.imshow(michigan,cmap=colormap_name,norm=norm)
    plt.colorbar()
    plt.clim(-352,352)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='Select a colormap:', index=154, layout=Layout(width='300px'), opti…

# %% [markdown]
# ## Some notes about the homework (and the dataset)

# %%
ufos = pd.read_csv('https://raw.githubusercontent.com/UIUC-iSchool-DataViz/is445_AOUAOG_fall2021/master/week05/data/ufo-scrubbed-geocoded-time-standardized-00.csv', 
                  names=["date", "city", "state", "country", 
                        "shape", "duration_seconds", "duration", 
                        "comment", "report_date", "latitude", "longitude"], 
                  parse_dates = ["date", "report_date"]) # tell pandas that these columns are dates

# %%
ufos.head()
# Out:
#                  date                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration_seconds    duration  \
# 0            2700.0  45 minutes
# 1            7200.0     1-2 hrs
# 2              20.0  20 seconds
# 3              20.0    1/2 hour
# 4             900.0  15 minutes
#
#                                              comment report_date   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
ufos
# Out:
#                      date                  city state country     shape  \
# 0     1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1     1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2     1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3     1956-10-10 21:00:00                  edna    tx      us    circle
# 4     1960-10-10 20:00:00               kaneohe    hi      us     light
# ...                   ...                   ...   ...     ...       ...
# 80327 2013-09-09 21:15:00             nashville    tn      us     light
# 80328 2013-09-09 22:00:00                 boise    id      us    circle
# 80329 2013-09-09 22:00:00                  napa    ca      us     other
# 80330 2013-09-09 22:20:00                vienna    va      us    circle
# 80331 2013-09-09 23:00:00                edmond    ok      us     cigar
#
#        duration_seconds    duration  \
# 0                2700.0  45 minutes
# 1                7200.0     1-2 hrs
# 2                  20.0  20 seconds
# 3                  20.0    1/2 hour
# 4                 900.0  15 minutes
# ...                 ...         ...
# 80327             600.0  10 minutes
# 80328            1200.0  20 minutes
# 80329            1200.0        hour
# 80330               5.0   5 seconds
# 80331            1020.0  17 minutes
#
#                                                  comment report_date  \
# 0      This event took place in early fall around 194...  2004-04-27
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16
# 2      Green/Orange circular disc over Chester&#44 En...  2008-01-21
# 3      My older brother and twin sister were leaving ...  2004-01-17
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...  2013-09-30
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 80329                                       Napa UFO&#44  2013-09-30
# 80330  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#         latitude   longitude
# 0      29.883056  -97.941111
# 1      29.384210  -98.581082
# 2      53.200000   -2.916667
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# ...          ...         ...
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
#
# [80332 rows x 11 columns]

# %%
# fill NaN's with something a little more useful
ufos = ufos.fillna({'country':'unknown', 
                   'state':'unknown', 
                   'shape':'unknown'})

# %%
ufos
# Out:
#                      date                  city    state  country     shape  \
# 0     1949-10-10 20:30:00            san marcos       tx       us  cylinder
# 1     1949-10-10 21:00:00          lackland afb       tx  unknown     light
# 2     1955-10-10 17:00:00  chester (uk/england)  unknown       gb    circle
# 3     1956-10-10 21:00:00                  edna       tx       us    circle
# 4     1960-10-10 20:00:00               kaneohe       hi       us     light
# ...                   ...                   ...      ...      ...       ...
# 80327 2013-09-09 21:15:00             nashville       tn       us     light
# 80328 2013-09-09 22:00:00                 boise       id       us    circle
# 80329 2013-09-09 22:00:00                  napa       ca       us     other
# 80330 2013-09-09 22:20:00                vienna       va       us    circle
# 80331 2013-09-09 23:00:00                edmond       ok       us     cigar
#
#        duration_seconds    duration  \
# 0                2700.0  45 minutes
# 1                7200.0     1-2 hrs
# 2                  20.0  20 seconds
# 3                  20.0    1/2 hour
# 4                 900.0  15 minutes
# ...                 ...         ...
# 80327             600.0  10 minutes
# 80328            1200.0  20 minutes
# 80329            1200.0        hour
# 80330               5.0   5 seconds
# 80331            1020.0  17 minutes
#
#                                                  comment report_date  \
# 0      This event took place in early fall around 194...  2004-04-27
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16
# 2      Green/Orange circular disc over Chester&#44 En...  2008-01-21
# 3      My older brother and twin sister were leaving ...  2004-01-17
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22
# ...                                                  ...         ...
# 80327  Round from the distance/slowly changing colors...  2013-09-30
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 80329                                       Napa UFO&#44  2013-09-30
# 80330  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
#
#         latitude   longitude
# 0      29.883056  -97.941111
# 1      29.384210  -98.581082
# 2      53.200000   -2.916667
# 3      28.978333  -96.645833
# 4      21.418056 -157.803611
# ...          ...         ...
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
#
# [80332 rows x 11 columns]

# %%
# downsample our data by pulling random indicies and only using rows that 
# correspond to those indicies
nsamples = 1000
downSampleMask = np.random.choice(range(len(ufos)-1),nsamples,replace=False)
# pull from 0-80331 a total of 1000 numbers, don't replace (don't double count)

# %%
downSampleMask
# Out:
# array([13722, 38416, 41520, 41194, 22065, 46747, 73167, 79298, 69078,
#        69287, 51329, 28703, 71178, 70983, 11103,  5070, 65528, 57170,
#          710, 46314, 24085, 57591, 37794, 29972, 71750, 42016, 70447,
#        13948, 32661,  6447, 73536,  1426, 49602, 75809, 15892, 36884,
#        25020, 35538, 20943, 32515,  4553, 41880, 48255, 35644,  7886,
#        74832, 56523, 37121,  5461,  2830, 18588, 32081, 12318, 25722,
#        46974, 13070, 72558, 61006, 36746, 75482, 26199, 78397, 58779,
#         4773, 62979, 72163, 74029, 46084, 68551, 19086, 22464, 75586,
#        27034, 64178, 23811, 46414, 16670,  6739, 57552, 36725, 32665,
#        55412, 56448, 38477, 59199, 45197, 72888, 48523, 50174, 60204,
#        73301, 18915, 68321, 76226, 32544, 67277,  7640, 28752, 79922,
#        14101, 44301, 78466, 58968, 26519, 56926,  3978, 22992, 28286,
#        76860, 31642, 49881, 23239, 62011, 76795, 20052, 19278, 80186,
#        45814,  3407, 22890,  6871,  3570, 76240, 63972, 51822, 57301,
#        24203, 13022,  1786, 39256, 77693, 38679,  4492, 51489, 29184,
#        53696, 52395, 15665, 73359, 17023, 60370, 32374, 46071, 78648,
#        33178, 71592, 48994,    74, 11408, 32285, 64654, 46618, 60943,
#        27892, 37228,   808, 69300, 22300, 33661, 26973, 16731, 19933,
#        40824, 46964, 37936,   541, 21546, 73317,  8207, 18844, 16286,
#        74424, 30128, 39973, 19427, 65764, 64805, 64632, 37483, 68853,
#        59243, 62701, 62259, 22145,  5779, 59743, 37095, 61539, 47691,
#        54018, 20686, 35041, 50924, 31664, 57173, 12025, 61245,  1139,
#        33934, 66566, 77560, 57924, 20499, 37069, 25773, 30274, 11882,
#        75025, 78661, 30825, 14644, 44991, 70840, 61771, 42028, 23179,
#         7718, 12000, 53511, 80258,  6555, 74570, 15746, 73076, 21852,
#        64812, 20233, 39266, 33058, 65350, 75229, 21128, 64529, 44592,
#        26985, 35504, 78708, 79110, 33757, 60326, 64931, 33952, 40509,
#         5685, 57234, 29021, 24400, 35578, 25645, 23448, 18357, 60058,
#        30154, 77948, 12949, 12154, 34940, 21499, 20048, 75719, 74954,
#        56582, 28732, 21761, 61911, 46674, 58682, 12072, 30542, 69717,
#        42261, 75240, 50478,  4226, 51901, 59870, 33221, 65729, 30960,
#        53695, 78531, 41487, 10727, 16838, 34541, 44571, 31667, 62618,
#        61551, 39245, 10790, 64720, 12870, 59535, 52818, 54735, 20009,
#        14317, 66288, 39100, 33014, 50845, 56737, 23712, 68615, 60114,
#        15401, 16478, 36956, 57414, 60384, 75072, 19982, 70640, 21518,
#        56741, 19733, 62803,  8824, 35149, 23577,   696, 58662, 32788,
#        11003, 18761, 27666, 61856, 46740,  8000, 67746, 12975, 10105,
#        10747, 37164,  3325, 76600, 50814, 76609, 15198, 27812, 12321,
#        69123, 32298, 26740, 18529, 40972, 44491, 26053, 74345, 52848,
#        39432, 24027, 80084, 70990, 33688, 16273, 71405, 35793, 74554,
#        29749, 18257,  8133, 59431, 65034, 57772, 71990, 68403, 74542,
#        28733, 18184, 34435, 63462,  9789, 19317, 62576,  7526, 22688,
#        35660, 47540, 46286, 16560, 26411, 77613, 39650, 17580, 23141,
#        79868, 53209, 33343, 63786, 19215, 63994, 29751, 11836,  7370,
#        53221,  2851, 52569, 28693, 52863, 55729, 46301, 51168, 29831,
#        44974, 32929, 58509, 23826, 50068, 65101, 21649, 47920, 53533,
#        73412, 20295,  4120, 17791, 37299, 77210, 27400,   935, 25230,
#        50069, 27011, 37377, 20769, 19988, 28497, 73492, 63222, 55707,
#        75132, 25614, 59383, 26271, 64607, 54621, 35331, 68000, 11940,
#        27821, 25427, 22113, 70543,  4734, 57893, 36083, 40948, 40656,
#        45728, 37888, 11835, 17586,  1433, 25595, 72900, 52645, 48263,
#        13774, 61034, 54718, 14928, 75801, 50882, 51010, 75100, 71102,
#        16514, 74656, 12187, 79094,   545, 29406, 55649, 66754, 68793,
#        73461, 57254, 73579, 55021, 32664, 20962, 19775, 57355,  9487,
#        76793, 44167, 41946, 36832,  5577, 76688, 27817, 59723, 72546,
#        60011, 66779, 37018, 14711, 48235, 56768, 29965, 13253, 27108,
#        64907, 27450, 44098, 29177, 35487, 42937, 10990, 13167, 77195,
#        34406, 35180, 62558,  3587, 68762,   309,   530, 41243,  5783,
#        24117, 34889, 15539, 12397,  3315, 72759,  3301,  3936, 63481,
#        24856, 24567, 23396, 57731, 53632, 57306, 17380, 49808, 51381,
#         8706, 38035, 14915, 47645, 57223, 50202, 45582, 58989, 56965,
#        67497, 29765, 48753, 40333, 36363, 59646, 53729, 69091, 20955,
#        47954, 35815, 74863, 22722, 13892,  5191, 59611, 53567, 79666,
#        44680, 52160, 40673,  3250, 29931, 77713, 27067,  2285, 62575,
#        52819, 63838, 40502, 20951, 53092, 31603, 79873,  6645, 23329,
#        15801, 40211, 13967, 74651, 40567, 29456, 70235, 59372, 45410,
#        10369, 45370, 77502, 12117, 41528, 55760,  4494, 62297,  5551,
#        59376,  5889,  2287, 63256, 41426, 19580, 70812,  3564, 49923,
#        18436,  1763, 56398, 36607, 70146, 61031, 75037, 31876, 35708,
#        22507, 76190, 22928, 60275,  3791, 67633, 69657, 42062, 48618,
#        49535, 46310, 43288, 76457,   656, 59877, 68271, 22267, 13038,
#        65492, 64394, 79652, 50798, 24583, 21917, 66415, 11259, 37318,
#        28299, 30342, 41986, 68431, 55255, 77273, 41598,  2520,  1400,
#        76890, 18462, 48767, 42997, 73670, 13025,  2485,  4590, 66497,
#        75779, 38160, 18338,  7703, 70279, 78403, 12613, 50387, 23567,
#        77160,  5726, 65089,  6660, 20228, 32585,  3130, 68769,  9447,
#        68144, 39923, 12824, 51424, 28125, 18343, 46014,  2729, 54626,
#        44513, 20220, 77567,   526, 48951, 72992, 68095, 14189,  7502,
#        57436, 12843, 40975, 25542, 51619, 44277, 10736, 67952, 14478,
#        12118,  6855, 37799, 68319, 80090, 14439,  9737,  3437, 80295,
#        24270, 37655, 15484,    93, 76328, 35443, 48693, 10720, 54719,
#        13356, 25293, 33370, 51890,  7884, 51858, 73936, 30579, 64624,
#         9130, 79664, 46695, 36830, 10246, 58051, 51045, 39727, 74480,
#         4192, 65986, 57590, 22736, 77478, 13837, 66317, 62794, 42239,
#         6883, 25380, 63874,  9282, 27488, 74309,  1290, 65901, 73501,
#        57431, 53577, 69275, 52981, 73149, 60832, 49405, 36861, 20567,
#        60138, 31172, 45193, 49650, 58203, 53046, 17755, 17232, 78420,
#         1576, 50910, 40934, 25319, 64671, 55977, 52185, 48186, 39672,
#        25416, 13588, 12217, 34030, 34149, 23508,  3104, 46950, 71970,
#        18871, 40707, 65243, 42364, 64829, 45522, 73868, 38816, 64339,
#        14851, 29760, 79551, 24970, 61567, 37984, 21536, 18051, 55281,
#        18952, 61281, 80204, 25018, 48281, 17017, 65830, 12468,  8418,
#        31681,  4908, 74081,  9470, 65475, 11416, 35609, 74167, 13548,
#         4882,  8915, 19006, 68235, 66448, 27110, 11311, 19267, 48774,
#        19224, 60480, 53110, 52606, 60699,  8758, 52465, 55872, 64789,
#        15060, 47270, 51831, 75475, 40272,  8062, 34399, 55304, 30489,
#        50325, 17761, 45112,  6685,  7002, 11210, 37516, 40098, 43615,
#        38185, 11635, 69398, 77942,  9088, 73663, 15389, 36293, 66495,
#        36358, 36121, 31284, 58924, 59710, 62776, 20522, 29984, 27580,
#         6177,  7359, 53139, 44851, 78277, 47685, 49083, 12416, 36033,
#         9182, 60155, 12294, 69753, 43283, 71030,  2786, 73114, 44698,
#        43463, 58280, 29220, 47709, 17230, 32648, 76232, 67596, 18229,
#        50093, 33932, 54507, 56397, 25904, 42005, 78575, 74614, 62689,
#        55730,  9468, 56546, 43189, 48982, 67735, 27741, 63049, 66372,
#        53452, 74595,  9801, 30463,  9322, 44860,  2584, 48407, 22373,
#        56443, 80316, 33338, 69692, 59140, 75528, 41513, 70385, 32882,
#        68203, 59130, 11296,  1444, 16643, 38858, 17006, 38707,   642,
#        28903, 35491,  6716, 48492, 66724, 75700,  7270, 72615,  3277,
#        21236, 16342, 76021, 16767, 65712, 50125, 27589, 67048, 41759,
#        45039, 33584, 22988, 56193, 72351, 78467, 47926, 19691, 10497,
#        63981, 71299, 42410,  6843, 29005, 17765, 33241, 49011, 66252,
#        74769])

# %%
ufosDS = ufos.loc[downSampleMask]

# %%
ufosDS
# Out:
#                      date                   city    state  country     shape  \
# 13722 2013-11-29 18:15:00              kennewick       wa       us  triangle
# 38416 1996-04-22 21:30:00                edmonds       wa       us   unknown
# 41520 1973-05-01 09:00:00           gaithersburg       md       us      disk
# 41194 2000-05-10 22:00:00              charlotte       nc       us  triangle
# 22065 2010-12-03 23:00:00  miami/fort lauderdale       fl  unknown     light
# ...                   ...                    ...      ...      ...       ...
# 17765 2009-12-12 19:00:00              daly city       ca       us  triangle
# 33241 2013-03-23 20:15:00               longwood       fl       us    sphere
# 49011 1993-06-15 21:00:00    mt. isa (australia)  unknown  unknown   unknown
# 66252 1977-08-15 02:00:00                   brea       ca       us     light
# 74769 2000-09-15 19:45:00                 wister       ok       us  triangle
#
#        duration_seconds     duration  \
# 13722            1500.0   25 minutes
# 38416               4.0       4 sec.
# 41520             240.0  3-4 minutes
# 41194             900.0   15 minutes
# 22065          259200.0       3 days
# ...                 ...          ...
# 17765            1800.0   30 minutes
# 33241             180.0  2-3 minutes
# 49011              30.0       30 sec
# 66252              25.0   25 seconds
# 74769              30.0   30 seconds
#
#                                                  comment report_date  \
# 13722   Triangle lights.  Kennewick&#44 WA&#44 11/29/13.  2013-12-02
# 38416  Man repts. seeing a round&#44 &quot;shapeless&...  1999-11-02
# 41520  Disk-shaped object with sequentially-flashing ...  2005-12-16
# 41194                  Silent craft floated over my head  2000-06-06
# 22065  Beams of Energy &amp; Illuminated Particles&#4...  2011-01-05
# ...                                                  ...         ...
# 17765  This is about as strange and bizzarre as it ca...  2010-02-14
# 33241                  2 Orange Orbs in the evening sky.  2013-05-15
# 49011  Driving home i saw a light hovering in the sky...  2000-12-02
# 66252                 A light emitted other other lights  2003-08-01
# 74769  Observed a dark colored&#44 unlighted triangul...  2000-12-02
#
#         latitude   longitude
# 13722  46.211389 -119.136111
# 38416  47.810833 -122.376111
# 41520  39.143333  -77.201667
# 41194  35.226944  -80.843333
# 22065  27.838145  -80.485438
# ...          ...         ...
# 17765  37.705833 -122.460833
# 33241  28.702778  -81.338611
# 49011 -20.724705  139.497462
# 66252  33.916667 -117.899167
# 74769  34.967222  -94.724444
#
# [1000 rows x 11 columns]

# %%
plt.plot(ufosDS['longitude'], ufosDS['latitude'], '.')
plt.show()

# %%
plt.plot(ufos['longitude'], ufos['latitude'], '.')
plt.show()

# %%
#plt.plot(ufos['longitude'], ufos['latitude'], '.', ms=20)
plt.plot(ufos['longitude'], ufos['latitude'], '.', markersize=10)

plt.show()

# %%
plt.scatter?

# %%
plt.scatter(ufosDS['longitude'], ufosDS['latitude'], 
           c=ufosDS['duration_seconds'], cmap='rainbow') # we know there are problems with rainbow!
plt.show()

# %%
ufosDS['duration_seconds'].min(), ufosDS['duration_seconds'].max()
# Out:
# (0.5, 604800.0)

# %%
plt.scatter(ufosDS['longitude'], ufosDS['latitude'], 
           c=np.log10(ufosDS['duration_seconds']), cmap='rainbow') # we know there are problems with rainbow!
plt.show()

# %%
# quick hint
fig, ax = plt.subplots(figsize=(10,5))
ufosDS.hist(column='longitude', ax=ax)
plt.show()

# %%
ufosDS.hist?

# %%
plt.scatter(ufosDS['longitude'], ufosDS['latitude'], 
           c=np.log10(ufosDS['duration_seconds']), 
            cmap='rainbow', s=200) # we know there are problems with rainbow!
plt.show()

# %%
plt.scatter?
