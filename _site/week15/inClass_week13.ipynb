# %% [markdown]
# # In Class Notebook, Week 13

# %% [markdown]
# You can always click on https://github.com/UIUC-iSchool-DataViz/is445_oauoag_fall2022/blob/master/week13/inClass_week13.ipynb
#
# Or past into the nbviewer interface for a plain-text rendering:
#
# https://kokes.github.io/nbviewer.js/viewer.html

# %%
import yt
# Out:
# /Users/jnaiman/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /Users/jnaiman/.config/yt/ytrc is deprecated in favor of /Users/jnaiman/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
ds = yt.load("/Users/jnaiman/Downloads/IsolatedGalaxy/galaxy0030/galaxy0030")
# Out:
# yt : [INFO     ] 2022-11-17 17:21:46,946 Parameters: current_time              = 0.0060000200028298
# yt : [INFO     ] 2022-11-17 17:21:46,947 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2022-11-17 17:21:46,948 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-11-17 17:21:46,949 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-11-17 17:21:46,950 Parameters: cosmological_simulation   = 0

# %%
ds.print_stats()
# Out:
# Parsing Hierarchy : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 173/173 [00:00<00:00, 10550.71it/s]
# yt : [INFO     ] 2022-11-17 17:22:19,995 Gathering a field list (this may take a moment.)
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	     1	         32768	            32
#   1	     8	         34304	            33
#   2	     8	        181888	            57
#   3	     8	        646968	            87
#   4	    15	        947856	            99
#   5	    51	        874128	            96
#   6	    18	        786328	            93
#   7	    28	        446776	            77
#   8	    36	        209400	            60
# ----------------------------------------------
#    	   173	       4160416
#
#
# t = 6.00002000e-03 = 1.39768066e+16 s = 4.42898275e+08 years
#
# Smallest Cell:
# 	Width: 1.221e-04 Mpc Mpc
# 	Width: 1.221e+02 pc pc
# ...

# %%
ds.field_list
# Out:
# [('all', 'creation_time'),
#  ('all', 'dynamical_time'),
#  ('all', 'metallicity_fraction'),
#  ('all', 'particle_index'),
#  ('all', 'particle_mass'),
#  ('all', 'particle_position_x'),
#  ('all', 'particle_position_y'),
#  ('all', 'particle_position_z'),
#  ('all', 'particle_type'),
#  ('all', 'particle_velocity_x'),
#  ('all', 'particle_velocity_y'),
#  ('all', 'particle_velocity_z'),
#  ('enzo', 'Average_creation_time'),
#  ('enzo', 'Bx'),
#  ('enzo', 'By'),
#  ('enzo', 'Bz'),
#  ('enzo', 'Cooling_Time'),
#  ('enzo', 'Dark_Matter_Density'),
#  ('enzo', 'Density'),
#  ('enzo', 'Electron_Density'),
#  ('enzo', 'Forming_Stellar_Mass_Density'),
#  ('enzo', 'Galaxy1Colour'),
#  ('enzo', 'Galaxy2Colour'),
#  ('enzo', 'HII_Density'),
#  ('enzo', 'HI_Density'),
#  ('enzo', 'HeIII_Density'),
#  ('enzo', 'HeII_Density'),
#  ('enzo', 'HeI_Density'),
#  ('enzo', 'MBHColour'),
#  ('enzo', 'Metal_Density'),
#  ('enzo', 'PhiField'),
#  ('enzo', 'Phi_pField'),
#  ('enzo', 'SFR_Density'),
# ...

# %%
ds.derived_field_list
# Out:
# [('all', 'age'),
#  ('all', 'creation_time'),
#  ('all', 'dynamical_time'),
#  ('all', 'mesh_id'),
#  ('all', 'metallicity_fraction'),
#  ('all', 'particle_angular_momentum'),
#  ('all', 'particle_angular_momentum_magnitude'),
#  ('all', 'particle_angular_momentum_x'),
#  ('all', 'particle_angular_momentum_y'),
#  ('all', 'particle_angular_momentum_z'),
#  ('all', 'particle_cylindrical_velocity_theta'),
#  ('all', 'particle_cylindrical_velocity_z'),
#  ('all', 'particle_index'),
#  ('all', 'particle_mass'),
#  ('all', 'particle_ones'),
#  ('all', 'particle_position'),
#  ('all', 'particle_position_cylindrical_radius'),
#  ('all', 'particle_position_cylindrical_theta'),
#  ('all', 'particle_position_cylindrical_z'),
#  ('all', 'particle_position_relative_x'),
#  ('all', 'particle_position_relative_y'),
#  ('all', 'particle_position_relative_z'),
#  ('all', 'particle_position_spherical_phi'),
#  ('all', 'particle_position_spherical_radius'),
# ...

# %%
ds.domain_right_edge, ds.domain_left_edge
# Out:
# (unyt_array([1., 1., 1.], 'code_length'),
#  unyt_array([0., 0., 0.], 'code_length'))

# %%
ds.r[:].max("density")
# Out:
# unyt_quantity(7.73426504e-24, 'g/cm**3')

# %%
ds.r[:].min("density")
# Out:
# unyt_quantity(8.47293751e-32, 'g/cm**3')

# %%
ds.r[:].argmax("density")
# Out:
# (unyt_quantity(0.50408936, 'code_length'),
#  unyt_quantity(0.49981689, 'code_length'),
#  unyt_quantity(0.50018311, 'code_length'))

# %%
import matplotlib.pyplot as plt
#plt.rcParams['figure.figsize'] = [2,2]

# %%
p = ds.r[:,:,0.5].plot("density")
# Out:
# yt : [INFO     ] 2022-11-17 17:28:54,963 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-17 17:28:54,965 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-17 17:28:54,969 Making a fixed resolution buffer of (density) 800 by 800
# yt : [INFO     ] 2022-11-17 17:28:55,028 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p.zoom(10)
# Out:
# yt : [INFO     ] 2022-11-17 17:29:47,369 Making a fixed resolution buffer of (density) 800 by 800
# yt : [INFO     ] 2022-11-17 17:29:47,384 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.units.kpc.get_cgs_equivalent()
# Out:
# cm

# %%
(yt.units.kpc**3).get_cgs_equivalent()
# Out:
# cm**3

# %%
p.set_unit("density","kg/m**3")
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p.annotate_velocity()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p2 = ds.r[:].max("density", axis="z").plot()
# Out:
# yt : [INFO     ] 2022-11-17 17:32:47,557 Projection completed
# yt : [INFO     ] 2022-11-17 17:32:47,558 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-17 17:32:47,558 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-17 17:32:47,560 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p2.zoom(10)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p3 = ds.r[0.1:0.9, 0.1:0.9, 0.55:0.65].max("density", axis="z").plot()
# Out:
# yt : [INFO     ] 2022-11-17 17:34:14,003 Projection completed
# yt : [INFO     ] 2022-11-17 17:34:14,004 xlim = 0.100000 0.900000
# yt : [INFO     ] 2022-11-17 17:34:14,005 ylim = 0.100000 0.900000
# yt : [INFO     ] 2022-11-17 17:34:14,006 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
pt = ds.r[0.1:0.9, 0.1:0.9, 0.55:0.65].mean("temperature",axis="z").plot()
# Out:
# yt : [INFO     ] 2022-11-17 17:35:17,841 Projection completed
# yt : [INFO     ] 2022-11-17 17:35:17,842 xlim = 0.100000 0.900000
# yt : [INFO     ] 2022-11-17 17:35:17,843 ylim = 0.100000 0.900000
# yt : [INFO     ] 2022-11-17 17:35:17,845 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ptw = ds.r[0.1:0.9, 0.1:0.9, 0.55:0.65].mean("temperature", weight="density",axis="z").plot()
# Out:
# yt : [INFO     ] 2022-11-17 17:36:25,405 Projection completed
# yt : [INFO     ] 2022-11-17 17:36:25,406 xlim = 0.100000 0.900000
# yt : [INFO     ] 2022-11-17 17:36:25,407 ylim = 0.100000 0.900000
# yt : [INFO     ] 2022-11-17 17:36:25,409 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ptw.annotate_grids()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds.r[:].profile("density","temperature").plot()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %% [markdown]
# ## Some quick volume rendering

# %%
sc = yt.create_scene(ds, 'density')

# %%
print(sc)
# Out:
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (galaxy0030): , center=[1.543e+24 1.543e+24 1.543e+24] cm cm, left_edge=[0. 0. 0.] cm cm, right_edge=[3.086e+24 3.086e+24 3.086e+24] cm cm transfer_function:None
# Camera:
#     <Camera Object>:
# 	position:[1. 1. 1.] code_length
# 	focus:[0.5 0.5 0.5] code_length
# 	north_vector:[ 0.81649658 -0.40824829 -0.40824829]
# 	width:[1.5 1.5 1.5] code_length
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:plane-parallel
# 	viewpoint:[-866025.33679714 -866025.33679714 -866025.33679714] code_length

# %%
sc.show()
# Out:
# yt : [INFO     ] 2022-11-17 17:41:45,864 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-11-17 17:41:45,867 Creating volume
# yt : [INFO     ] 2022-11-17 17:41:47,877 Creating transfer function
# yt : [INFO     ] 2022-11-17 17:41:47,877 Calculating data bounds. This may take a while. Set the TransferFunctionHelper.bounds to avoid this.
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (galaxy0030): , center=[1.543e+24 1.543e+24 1.543e+24] cm cm, left_edge=[0. 0. 0.] cm cm, right_edge=[3.086e+24 3.086e+24 3.086e+24] cm cm transfer_function:None
# Camera:
#     <Camera Object>:
# 	position:[1. 1. 1.] code_length
# 	focus:[0.5 0.5 0.5] code_length
# 	north_vector:[ 0.81649658 -0.40824829 -0.40824829]
# 	width:[1.5 1.5 1.5] code_length
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:plane-parallel
# 	viewpoint:[-866025.33679714 -866025.33679714 -866025.33679714] code_length

# %%
sc.camera.width = (300, 'kpc')
sc.show()
# Out:
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (galaxy0030): , center=[1.543e+24 1.543e+24 1.543e+24] cm cm, left_edge=[0. 0. 0.] cm cm, right_edge=[3.086e+24 3.086e+24 3.086e+24] cm cm transfer_function:<Color Transfer Function Object>:
# x_bounds:[-31, -23] nbins:512 features:
# 	('gaussian', 'location(x):-31', 'width(x):0.002', 'height(y):(0.073,   0, 0.084, 0.001)')
# 	('gaussian', 'location(x):-30', 'width(x):0.002', 'height(y):(0.35,   0, 0.62, 0.0022)')
# 	('gaussian', 'location(x):-29', 'width(x):0.002', 'height(y):(  0, 0.26, 0.87, 0.0046)')
# 	('gaussian', 'location(x):-28', 'width(x):0.002', 'height(y):(  0, 0.65, 0.72, 0.01)')
# 	('gaussian', 'location(x):-28', 'width(x):0.002', 'height(y):(  0, 0.6, 0.031, 0.022)')
# 	('gaussian', 'location(x):-27', 'width(x):0.002', 'height(y):(  0, 0.87,   0, 0.046)')
# 	('gaussian', 'location(x):-26', 'width(x):0.002', 'height(y):(0.78, 0.98,   0, 0.1)')
# ...

# %%
sc.camera.switch_orientation?

# %%
sc = yt.create_scene(ds,'density')
#sc.camera_width = (300, 'kpc')
sc.camera.width = (300, 'kpc')
sc.camera.switch_orientation()
sc.show()
# Out:
# yt : [INFO     ] 2022-11-17 17:44:16,781 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-11-17 17:44:16,782 Creating volume
# yt : [INFO     ] 2022-11-17 17:44:18,417 Creating transfer function
# yt : [INFO     ] 2022-11-17 17:44:18,417 Calculating data bounds. This may take a while. Set the TransferFunctionHelper.bounds to avoid this.
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (galaxy0030): , center=[1.543e+24 1.543e+24 1.543e+24] cm cm, left_edge=[0. 0. 0.] cm cm, right_edge=[3.086e+24 3.086e+24 3.086e+24] cm cm transfer_function:None
# Camera:
#     <Camera Object>:
# 	position:[1. 1. 1.] code_length
# 	focus:[0.5 0.5 0.5] code_length
# 	north_vector:[ 0.81649658 -0.40824829 -0.40824829] dimensionless
# 	width:[0.29996866 0.29996866 0.29996866] unitary
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:plane-parallel
# 	viewpoint:[-173186.5712339 -173186.5712339 -173186.5712339] code_length
