# %% [markdown]
# # In Class Notebook, Week 01

# %% [markdown]
# You can always paste the URL of this notebook (https://github.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2022/blob/master/week01/inClass_week01.ipynb ) into the nbviewer interface for a plain-text rendering:
#
# https://kokes.github.io/nbviewer.js/viewer.html
#
# I am typing a thing.
#
# I am typing another thing.

# %%
4+5
# Out:
# 9

# %% [markdown]
# But I can write things like normal.
#
# # A large header
#
# ## I can make a smaller header
#
# ### Even smaller
#
# #### Super smaller (smallest)

# %% [markdown]
# Make some ordered lists:
#  1. thing number 1
#  1. next thing
#  1. a final thing
#
# Unordered lists:
#  * bullet point 1
#  * bullet point 2
#
# $\frac{x}{y} = \frac{2}{3}$

# %%
print('hi there')
# Out:
# hi there

# %%
'hi there'
# Out:
# 'hi there'

# %% [markdown]
# ## Simple plots
#
# (ESC-M hot key for markdown cells)

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import datetime
import numpy as np

# %%
time = [20070101, 20070401, 20070701, 20071001, 20080101, 20080401, 20080701, 20081001, 20090101]

# %%
time
# Out:
# [20070101,
#  20070401,
#  20070701,
#  20071001,
#  20080101,
#  20080401,
#  20080701,
#  20081001,
#  20090101]

# %%
plt.plot(time) # default matplotlib line plot
plt.xlabel('Measurement #')
plt.ylabel('YearMonthDay')
# Out:
# Text(0, 0.5, 'YearMonthDay')

# %%
gdp = [14233.2, 14422.3, 14569.7, 14685.3, 14668.4, 14813.0, 14843.0, 14549.9, 14383.9]

# %%
gdp # gross domestic product (of USA) in Billions
# Out:
# [14233.2,
#  14422.3,
#  14569.7,
#  14685.3,
#  14668.4,
#  14813.0,
#  14843.0,
#  14549.9,
#  14383.9]

# %%
plt.plot(time, gdp) # x-axis = time in YearMonthDay; y-axis=GDP in Billions
plt.xlabel('Time in YearMonthDay')
plt.ylabel('GDP in Billions')
# Out:
# Text(0, 0.5, 'GDP in Billions')

# %%
plt.plot(time,gdp,'o-') # this will be a line + dot plot
plt.xlabel('Time in YearMonthDay')
plt.ylabel('GDP in Billions')
# Out:
# Text(0, 0.5, 'GDP in Billions')

# %%
date = [] # empty array to fill with formatted dates
for t in time: 
    print(t)
    d = datetime.datetime.strptime(str(t),'%Y%m%d')
    print(d)
    date.append(d) # create a list of datetime-formatted objects
# Out:
# 20070101
# 2007-01-01 00:00:00
# 20070401
# 2007-04-01 00:00:00
# 20070701
# 2007-07-01 00:00:00
# 20071001
# 2007-10-01 00:00:00
# 20080101
# 2008-01-01 00:00:00
# 20080401
# 2008-04-01 00:00:00
# 20080701
# 2008-07-01 00:00:00
# 20081001
# 2008-10-01 00:00:00
# 20090101
# 2009-01-01 00:00:00

# %%
d
# Out:
# datetime.datetime(2009, 1, 1, 0, 0)

# %%
date
# Out:
# [datetime.datetime(2007, 1, 1, 0, 0),
#  datetime.datetime(2007, 4, 1, 0, 0),
#  datetime.datetime(2007, 7, 1, 0, 0),
#  datetime.datetime(2007, 10, 1, 0, 0),
#  datetime.datetime(2008, 1, 1, 0, 0),
#  datetime.datetime(2008, 4, 1, 0, 0),
#  datetime.datetime(2008, 7, 1, 0, 0),
#  datetime.datetime(2008, 10, 1, 0, 0),
#  datetime.datetime(2009, 1, 1, 0, 0)]

# %%
plt.plot(date,gdp,'o-') # using datetime objects

# %%
fig, ax = plt.subplots(figsize=(8,4)) # created fig (canvas) and axes objects (where we put specific plots)
ax.plot(date,gdp,'o-') # making a line+dot plot on a specific axis (could be multiple!)
plt.show() # showing our plot (for our purposes gets rid of the memory address stuff)

# %%
style = 'fivethirtyeight'
with plt.style.context(style): # only apply this to this particular 
    fig, ax = plt.subplots(figsize=(8,4))
    ax.plot(date,gdp,'o-')
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4)) # created fig (canvas) and axes objects (where we put specific plots)
ax.plot(date,gdp,'o-') # making a line+dot plot on a specific axis (could be multiple!)
plt.show() # showing our plot (for our purposes gets rid of the memory address stuff)

# %%
#plt.style.available # all available

# %%
def make_gdp_plot(style):
    with plt.style.context(style): # only apply this to this particular 
        # to move this over as a chunk I did COMMAND+]
        fig, ax = plt.subplots(figsize=(8,4))
        ax.plot(date,gdp,'o-')
        plt.show()

# %%
make_gdp_plot('fivethirtyeight')

# %%
make_gdp_plot('ggplot')

# %% [markdown]
# ## Reading in some image data

# %%
from PIL import Image

# %%
im = Image.open('/Users/jnaiman/Downloads/stitch_reworked.png') # note: we did a TAB to complete the search

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=430x483>

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
imgdata = np.array(im) # from PIL image into numpy array

# %%
imgdata.shape
# Out:
# (483, 430, 4)

# %%
fig,ax = plt.subplots(figsize=(4,4))
ax.imshow(imgdata) # function to plot image-like data
plt.show()

# %%
np.unique(imgdata)
# Out:
# array([  0,  22,  33, 126, 255], dtype=uint8)

# %%
np.unique(imgdata[:,:,0])
# Out:
# array([  0, 126, 255], dtype=uint8)
