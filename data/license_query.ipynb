# %% [markdown]
# Getting data from: https://data.illinois.gov/dataset/professional-licensing/resource/beef79ab-b679-4b0a-960a-05c218a619ba

# %%
save_file = '/Users/jnaiman/Downloads/tmp/license_records100000.csv'

# %%
import urllib
import json
import pandas as pd

# %%
#url = 'https://data.illinois.gov/api/3/action/datastore_search?resource_id=beef79ab-b679-4b0a-960a-05c218a619ba&limit=5&q=title:jones'  
#url = 'https://data.illinois.gov/api/3/action/datastore_search?resource_id=beef79ab-b679-4b0a-960a-05c218a619ba&limit=5'  
url = 'https://data.illinois.gov/api/3/action/datastore_search?resource_id=beef79ab-b679-4b0a-960a-05c218a619ba&limit=100000'  
fileobj = urllib.request.urlopen(url)
data = fileobj.read().decode('utf-8')

# %%
j = json.loads(data)

# %%
df = pd.DataFrame(j['result']['records'])

# %%
df
# Out:
#            _id   License Type                    Description License Number  \
# 0      2029945  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041266221
# 1      2029946  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041266224
# 2      2029947  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041266225
# 3      2029948  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041266228
# 4      2029949  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041266229
# ...        ...            ...                            ...            ...
# 99995  2129961  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041341283
# 99996  2129962  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041341284
# 99997  2129963  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041341289
# 99998  2129964  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041341293
# 99999  2129965  NURSING BOARD  REGISTERED PROFESSIONAL NURSE      041341311
#
#       License Status Business Title  First Name Middle         Last Name  ...  \
# 0           INACTIVE        N           SUSAN L                   KOZENY  ...
# 1           INACTIVE        N         ELIZABETH         BADDOUR ISRABIAN  ...
# 2        NOT RENEWED        N         JERI LYNN                     RYAN  ...
# 3        NOT RENEWED        N           JOANN R                  MATHEWS  ...
# 4        NOT RENEWED        N        KATHLEEN M                 FAULKNER  ...
# ...              ...      ...   ...         ...    ...               ...  ...
# 99995       INACTIVE        N              MARY      B           SCHULTZ  ...
# 99996       INACTIVE        N        CASSIOPEIA      R            HOOVER  ...
# 99997         ACTIVE        N             WANDA      M          GARFIELD  ...
# 99998         ACTIVE        N             JULIE      A          MCLELLAN  ...
# 99999    NOT RENEWED        N          JENNIFER      A           SHEAFOR  ...
#
#       Specialty/Qualifier Controlled Substance Schedule  \
# 0                    None                          None
# 1                    None                          None
# 2                    None                          None
# 3                    None                          None
# 4                    None                          None
# ...                   ...                           ...
# 99995                None                          None
# 99996                None                          None
# 99997                None                          None
# 99998                None                          None
# 99999                None                          None
#
#       Delegated Controlled Substance Schedule Ever Disciplined  \
# 0                                        None                N
# 1                                        None                N
# 2                                        None                N
# 3                                        None                N
# 4                                        None                N
# ...                                       ...              ...
# 99995                                    None                N
# 99996                                    None                N
# 99997                                    None                N
# 99998                                    None                N
# 99999                                    None                N
#
#       LastModifiedDate Case Number Action Discipline Start Date  \
# 0           09/27/2006        None   None                  None
# 1           09/27/2006        None   None                  None
# 2           09/27/2006        None   None                  None
# 3           10/09/2006        None   None                  None
# 4           07/19/2018        None   None                  None
# ...                ...         ...    ...                   ...
# 99995       03/05/2010        None   None                  None
# 99996       03/11/2008        None   None                  None
# 99997       05/02/2022        None   None                  None
# 99998       05/02/2022        None   None                  None
# 99999       07/10/2012        None   None                  None
#
#       Discipline End Date Discipline Reason
# 0                    None              None
# 1                    None              None
# 2                    None              None
# 3                    None              None
# 4                    None              None
# ...                   ...               ...
# 99995                None              None
# 99996                None              None
# 99997                None              None
# 99998                None              None
# 99999                None              None
#
# [100000 rows x 31 columns]

# %%
#df.to_csv?

# %%
df.to_csv(save_file,index=False)

# %%
dfin = pd.read_csv(save_file)
# Out:
# /Users/jnaiman/opt/anaconda3/envs/DataViz/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (10,13,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
dfin.head()
# Out:
#        _id   License Type                    Description  License Number  \
# 0  2029945  NURSING BOARD  REGISTERED PROFESSIONAL NURSE        41266221
# 1  2029946  NURSING BOARD  REGISTERED PROFESSIONAL NURSE        41266224
# 2  2029947  NURSING BOARD  REGISTERED PROFESSIONAL NURSE        41266225
# 3  2029948  NURSING BOARD  REGISTERED PROFESSIONAL NURSE        41266228
# 4  2029949  NURSING BOARD  REGISTERED PROFESSIONAL NURSE        41266229
#
#   License Status Business Title  First Name Middle         Last Name  ...  \
# 0       INACTIVE        N   NaN     SUSAN L    NaN            KOZENY  ...
# 1       INACTIVE        N   NaN   ELIZABETH    NaN  BADDOUR ISRABIAN  ...
# 2    NOT RENEWED        N   NaN   JERI LYNN    NaN              RYAN  ...
# 3    NOT RENEWED        N   NaN     JOANN R    NaN           MATHEWS  ...
# 4    NOT RENEWED        N   NaN  KATHLEEN M    NaN          FAULKNER  ...
#
#   Specialty/Qualifier Controlled Substance Schedule  \
# 0                None                          None
# 1                None                          None
# 2                None                          None
# 3                None                          None
# 4                None                          None
#
#   Delegated Controlled Substance Schedule Ever Disciplined LastModifiedDate  \
# 0                                    None                N       09/27/2006
# 1                                    None                N       09/27/2006
# 2                                    None                N       09/27/2006
# 3                                    None                N       10/09/2006
# 4                                    None                N       07/19/2018
#
#   Case Number Action Discipline Start Date Discipline End Date  \
# 0        None   None                  None                None
# 1        None   None                  None                None
# 2        None   None                  None                None
# 3        None   None                  None                None
# 4        None   None                  None                None
#
#   Discipline Reason
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
#
# [5 rows x 31 columns]

# %%
dfin.columns
# Out:
# Index(['_id', 'License Type', 'Description', 'License Number',
#        'License Status', 'Business', 'Title', 'First Name', 'Middle',
#        'Last Name', 'Prefix', 'Suffix', 'Business Name', 'BusinessDBA',
#        'Original Issue Date', 'Effective Date', 'Expiration Date', 'City',
#        'State', 'Zip', 'County', 'Specialty/Qualifier',
#        'Controlled Substance Schedule',
#        'Delegated Controlled Substance Schedule', 'Ever Disciplined',
#        'LastModifiedDate', 'Case Number', 'Action', 'Discipline Start Date',
#        'Discipline End Date', 'Discipline Reason'],
#       dtype='object')

# %%
dfin['Original Issue Date']
# Out:
# 0        11/13/1991
# 1        11/14/1991
# 2        11/14/1991
# 3        11/14/1991
# 4        11/14/1991
#             ...
# 99995    07/27/2004
# 99996    07/27/2004
# 99997    07/27/2004
# 99998    07/27/2004
# 99999    07/28/2004
# Name: Original Issue Date, Length: 100000, dtype: object

# %%
dfin['Expiration Date']
# Out:
# 0        05/31/1992
# 1        05/31/1998
# 2        05/31/1996
# 3        05/31/2004
# 4        05/31/2018
#             ...
# 99995    05/31/2010
# 99996    05/31/2008
# 99997    08/31/2022
# 99998    08/31/2022
# 99999    05/31/2012
# Name: Expiration Date, Length: 100000, dtype: object
